# %% [markdown]
# ## Part of Speech Tagging with Hidden Markov Models
# - ![image.png](attachment:image.png)

# %%
# http://bit.ly/313d6Sq
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from collections import Counter, defaultdict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution

# %%
# %run "Helpers/helpers.py"

# %% [markdown]
# ## Example from the Brown corpus dataset
# - ![image.png](attachment:image.png)

# %%
data = Dataset("tags-universal.txt", "brown-universal.txt", train_test_split=0.8)
print("There are {} sentences in the corpus".format(len(data)))
print("There are {} sentences in the training dataset".format(len(data.training_set)))
print("There are {} sentences in the testing dataset".format(len(data.testing_set)))
# Out:
# There are 57340 sentences in the corpus
# There are 45872 sentences in the training dataset
# There are 11468 sentences in the testing dataset

# %% [markdown]
# ## Sentences
# - `Dataset.sentences` is a dictionary of all sentences in the training corpus
# - the unique sentence identifier is the key, a tuple of (words,tag) is the values

# %%
key = 'b100-38532'
data.sentences[key]
# Out:
# Sentence(words=('Perhaps', 'it', 'was', 'right', ';', ';'), tags=('ADV', 'PRON', 'VERB', 'ADJ', '.', '.'))

# %%
print(f"Sentence: {key}")
print(f"words:\n\t{data.sentences[key].words}")
print(f"tags:\n\t{data.sentences[key].tags}")
# Out:
# Sentence: b100-38532
# words:
# 	('Perhaps', 'it', 'was', 'right', ';', ';')
# tags:
# 	('ADV', 'PRON', 'VERB', 'ADJ', '.', '.')

# %% [markdown]
# ## Counting Unique Elements

# %%
print("There are a total of {} samples of {} unique words in the corpus".format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set".format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set".format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in test set that are missing in the training set. ".format(len(data.testing_set.vocab - data.training_set.vocab)))
# Out:
# There are a total of 1161192 samples of 56057 unique words in the corpus
# There are 928458 samples of 50536 unique words in the training set
# There are 232734 samples of 25112 unique words in the testing set
# There are 5521 words in test set that are missing in the training set.

# %% [markdown]
# ## Pair Counts
# - computes the joint frequency counts for two input sequences.

# %%
def pair_counts(sequences_A, sequences_B):
    dcount = defaultdict(dict)
    d = dict(Counter(list(zip(sequences_A, sequences_B))))
    for key, value in d.items():
        dcount[key[0]][key[1]] = value
    return dcount

tags = [tag for word, tag in data.stream()]
words = [word for word, tag in data.stream()]
emmission_counts = pair_counts(tags, words)

# %% [markdown]
# ## Most Frequent Class Tagger

# %%
FakeState = namedtuple("FakeState", "name")

# %%
class MFCTagger:
    missing = FakeState(name="<MISSING>")
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
word_counts = pair_counts(words, tags)

# %%
mfc_table = {}

for word in data.training_set.vocab:
    mfc_table[word] = max(word_counts[word], key = word_counts[word].get)
    
mfc_model = MFCTagger(mfc_table)

# %%
mfc_table
# Out:
# {'microphoning': 'NOUN',
#  'premieres': 'NOUN',
#  'Skolovsky': 'NOUN',
#  'enmity': 'NOUN',
#  'Frankly': 'ADV',
#  'professional': 'ADJ',
#  'Va.': 'NOUN',
#  'worth': 'ADJ',
#  '15.5': 'NUM',
#  'leased': 'VERB',
#  'shortened': 'VERB',
#  "everybody's": 'NOUN',
#  'investigative': 'ADJ',
#  'quintet': 'NOUN',
#  'summarizes': 'VERB',
#  'preferred': 'VERB',
#  'Lindskog': 'NOUN',
#  'voulez': 'X',
#  'superiority': 'NOUN',
#  'recheck': 'VERB',
#  'Confessions': 'NOUN',
#  'States-Yugoslav': 'NOUN',
#  '$184': 'NOUN',
#  'shortest': 'ADJ',
#  'rent': 'VERB',
#  "Redbirds'": 'NOUN',
#  'thet': 'ADP',
#  'anthems': 'NOUN',
#  'GE': 'NOUN',
#  'kava': 'NOUN',
#  'undergone': 'VERB',
#  'pug-nosed': 'ADJ',
#  'conceptualization': 'NOUN',
#  'Washington-Oregon': 'NOUN',
#  'Corrections': 'NOUN',
#  'edging': 'VERB',
#  'substantial': 'ADJ',
#  'helmets': 'NOUN',
#  'airflow': 'NOUN',
#  'N.Y.U.': 'NOUN',
#  'years': 'NOUN',
#  'floundering': 'VERB',
#  'Troy': 'NOUN',
#  'disarm': 'VERB',
#  'Doolin': 'NOUN',
#  '$.07': 'NOUN',
#  'Everywhere': 'ADV',
#  'locust': 'NOUN',
#  'Tertre': 'X',
#  'rectlinearly': 'ADV',
#  'jabs': 'NOUN',
#  'reluctance': 'NOUN',
#  'willful': 'ADJ',
#  'Hendl': 'NOUN',
#  'ever-growing': 'ADJ',
#  'being': 'VERB',
#  'artifacts': 'NOUN',
#  'specie': 'X',
#  'today': 'NOUN',
#  'high-ceilinged': 'ADJ',
#  'breathtaking': 'ADJ',
#  'ignores': 'VERB',
#  'luring': 'VERB',
#  'drovers': 'NOUN',
#  'pedestrians': 'NOUN',
#  'Ohio': 'NOUN',
#  'supportive': 'ADJ',
#  'ruffled': 'VERB',
#  'bombings': 'NOUN',
#  'S.': 'NOUN',
#  'Pius': 'NOUN',
#  'ducts': 'NOUN',
#  'Production': 'NOUN',
#  'idioms': 'NOUN',
#  'Corporations': 'NOUN',
#  'Loud': 'ADJ',
#  'electrically': 'ADV',
#  'SMU': 'NOUN',
#  'Etudes': 'NOUN',
#  'intrusions': 'NOUN',
#  'Finley': 'NOUN',
#  'Bookwalter': 'NOUN',
#  'sideboard': 'NOUN',
#  'closely': 'ADV',
#  'unfastened': 'VERB',
#  'slowest': 'ADJ',
#  'fireman': 'NOUN',
#  'clocking': 'NOUN',
#  'Emanuele': 'NOUN',
#  'happen': 'VERB',
#  'enrollments': 'NOUN',
#  'local': 'ADJ',
#  'inexpressible': 'ADJ',
#  'qualitative': 'ADJ',
#  'Trivia': 'NOUN',
#  'nonchurchgoing': 'ADJ',
#  'wicked': 'ADJ',
#  'endosperm': 'NOUN',
#  'tacking': 'VERB',
#  '8,280': 'NUM',
#  "Plato's": 'NOUN',
#  'wrestling': 'VERB',
#  '360': 'NUM',
#  'Fractions': 'NOUN',
#  'Galway': 'NOUN',
#  'rabbits': 'NOUN',
#  'theare': 'PRT',
#  'grubby': 'ADJ',
#  'Organization': 'NOUN',
#  'typhus': 'NOUN',
#  'Birkhead': 'NOUN',
#  'joy': 'NOUN',
#  'cross-section': 'NOUN',
#  "Beowulf's": 'NOUN',
#  'undo': 'VERB',
#  'jaw': 'NOUN',
#  'macromolecular': 'ADJ',
#  'hearers': 'NOUN',
#  'Invitation': 'NOUN',
#  'Room': 'NOUN',
#  'stabbed': 'VERB',
#  'cholelithiasis': 'NOUN',
#  'Elisabeth': 'NOUN',
#  'clairvoyance': 'NOUN',
#  'tubes': 'NOUN',
#  'clauses': 'NOUN',
#  'vibrato': 'NOUN',
#  'Howorth': 'NOUN',
#  '**yl': 'NOUN',
#  'Official': 'ADJ',
#  'Dynafac': 'NOUN',
#  'Carlisle': 'NOUN',
#  'writer': 'NOUN',
#  'brad': 'NOUN',
#  'bumped': 'VERB',
#  'Weigand': 'NOUN',
#  'slides': 'NOUN',
#  "Jr.'s": 'NOUN',
#  'blunt': 'ADJ',
#  'this': 'DET',
#  'cypress': 'NOUN',
#  "Anselm's": 'NOUN',
#  'Structures': 'NOUN',
#  'trail': 'NOUN',
#  'Minnie': 'NOUN',
#  'Putas': 'X',
#  'Powicke': 'NOUN',
#  'restructured': 'VERB',
#  'eight-thirty': 'NUM',
#  'pronto': 'ADV',
#  'Injun': 'NOUN',
#  'pastoral': 'ADJ',
#  'climates': 'NOUN',
#  'ex-marine': 'NOUN',
#  'cosmological': 'ADJ',
#  'epitomizes': 'VERB',
#  '0600': 'NUM',
#  'cornfield': 'NOUN',
#  'Clapping': 'VERB',
#  'nonstop': 'NOUN',
#  'Expedition': 'NOUN',
#  'splendidly': 'ADV',
#  'Fascism': 'NOUN',
#  'firepower': 'NOUN',
#  'murdered': 'VERB',
#  'Fairless': 'NOUN',
#  'relaxed': 'VERB',
#  'Series': 'NOUN',
#  'planets': 'NOUN',
#  "oystchers'll": 'PRT',
#  'Terror': 'NOUN',
#  'separable': 'ADJ',
#  'activated': 'VERB',
#  'amulets': 'NOUN',
#  'intending': 'VERB',
#  'Caution': 'NOUN',
#  'Valuable': 'ADJ',
#  'enlarged': 'VERB',
#  'cost-of-living': 'NOUN',
#  'poshest': 'ADJ',
#  'prognosticator': 'NOUN',
#  'mastered': 'VERB',
#  'linguistically': 'ADV',
#  'off-shore': 'ADV',
#  'Hanover-Misty': 'NOUN',
#  'ink': 'NOUN',
#  'Epicurus': 'NOUN',
#  'industry': 'NOUN',
#  'Lockheed': 'NOUN',
#  'tormented': 'VERB',
#  'Waterloo': 'NOUN',
#  'Copley': 'NOUN',
#  'obey': 'VERB',
#  'twinkle': 'NOUN',
#  'Furnishes': 'VERB',
#  'Dussa': 'NOUN',
#  'skouting': 'VERB',
#  'Florican-My': 'NOUN',
#  'area': 'NOUN',
#  "Hershey's": 'NOUN',
#  'eastern': 'ADJ',
#  'Adios-On': 'NOUN',
#  'Bontempo': 'NOUN',
#  'correspondents': 'NOUN',
#  'Carbones': 'NOUN',
#  'frangipani': 'NOUN',
#  'tearing': 'VERB',
#  'dashed': 'VERB',
#  'unbeknownst': 'ADJ',
#  'patience': 'NOUN',
#  'defending': 'VERB',
#  'schooling': 'NOUN',
#  'coquette': 'NOUN',
#  'multilateral': 'ADJ',
#  'concededly': 'ADV',
#  'unintentionally': 'ADV',
#  'Hub': 'NOUN',
#  'Imperial': 'ADJ',
#  'compels': 'VERB',
#  'deep-sea': 'ADJ',
#  'Co.': 'NOUN',
#  'repayment': 'NOUN',
#  'Sid': 'NOUN',
#  'black': 'ADJ',
#  'diversity': 'NOUN',
#  'served': 'VERB',
#  'streetlight': 'NOUN',
#  'detention': 'NOUN',
#  'equality': 'NOUN',
#  'junkies': 'NOUN',
#  'Thermogravimetric': 'ADJ',
#  'contractors': 'NOUN',
#  'Vastly': 'ADV',
#  'indicators': 'NOUN',
#  'Wagner': 'NOUN',
#  'Polish': 'ADJ',
#  'Compare': 'VERB',
#  'explanation': 'NOUN',
#  'vectors': 'NOUN',
#  "husband's": 'NOUN',
#  'Maynard': 'NOUN',
#  'prolusions': 'NOUN',
#  'Decisions': 'NOUN',
#  'totalitarianism': 'NOUN',
#  'field': 'NOUN',
#  'Antonini': 'NOUN',
#  'Housed': 'VERB',
#  'Visiting': 'VERB',
#  'Ron': 'NOUN',
#  'Naxos': 'NOUN',
#  'likened': 'VERB',
#  'rumored': 'VERB',
#  'afterwards': 'ADV',
#  'Southern-Republican': 'NOUN',
#  "we've": 'PRT',
#  'vaccination': 'NOUN',
#  'Pankowski': 'NOUN',
#  'rifled': 'VERB',
#  'rearrange': 'VERB',
#  'tiller': 'NOUN',
#  'depressingly': 'ADV',
#  'heyday': 'NOUN',
#  'Otherwise': 'ADV',
#  'Westwood': 'NOUN',
#  'citizen': 'NOUN',
#  'dishonest': 'ADJ',
#  'redoubled': 'VERB',
#  'fussing': 'VERB',
#  'ads': 'NOUN',
#  'Bystrzyca': 'NOUN',
#  'deliver': 'VERB',
#  'borne': 'VERB',
#  'Jacksons': 'NOUN',
#  'Stock': 'NOUN',
#  'transducer': 'NOUN',
#  '{0,T}': 'NOUN',
#  'Confederacy': 'NOUN',
#  'megaton': 'NOUN',
#  'alibi': 'NOUN',
#  'Hammett': 'NOUN',
#  'Effectively': 'ADV',
#  'straggled': 'VERB',
#  'choose': 'VERB',
#  'glass': 'NOUN',
#  'Trig': 'NOUN',
#  'bathed': 'VERB',
#  "bustin'": 'VERB',
#  '1900': 'NUM',
#  'countries': 'NOUN',
#  'microcosm': 'NOUN',
#  'retrieve': 'VERB',
#  'Salsich': 'NOUN',
#  'Dever': 'NOUN',
#  '20-22': 'NUM',
#  'dies': 'VERB',
#  'verses': 'NOUN',
#  'Buckenham': 'NOUN',
#  'revel': 'NOUN',
#  '20-piece': 'NOUN',
#  'Preserve': 'NOUN',
#  'Bavaria': 'NOUN',
#  'carob': 'X',
#  'provides': 'VERB',
#  'Calcutta': 'NOUN',
#  '3:30': 'NUM',
#  'face-to-face': 'ADJ',
#  'vaudeville': 'NOUN',
#  'opinions': 'NOUN',
#  'double-glaze': 'VERB',
#  'grovel': 'VERB',
#  'unparalleled': 'ADJ',
#  'arylesterases': 'NOUN',
#  'fineness': 'NOUN',
#  'banquet': 'NOUN',
#  'contested': 'VERB',
#  "Ellison's": 'NOUN',
#  'adores': 'VERB',
#  'cowhands': 'NOUN',
#  'inadequacy': 'NOUN',
#  'gangsters': 'NOUN',
#  'Sheraton-Dallas': 'NOUN',
#  'anyways': 'ADV',
#  'underlined': 'VERB',
#  'spin': 'VERB',
#  'readings': 'NOUN',
#  'dexamethasone': 'NOUN',
#  'splitting': 'VERB',
#  'incite': 'VERB',
#  'disbelief': 'NOUN',
#  "duds'd": 'PRT',
#  'immense': 'ADJ',
#  'auction': 'NOUN',
#  'Probable': 'ADJ',
#  "contractor's": 'NOUN',
#  'Dizzy': 'NOUN',
#  'rocky': 'ADJ',
#  'confiding': 'VERB',
#  'daughters': 'NOUN',
#  'restatement': 'NOUN',
#  'screeched': 'VERB',
#  'obstacles': 'NOUN',
#  'shifty': 'ADJ',
#  "Wyndham's": 'NOUN',
#  'pavement': 'NOUN',
#  '1.58': 'NUM',
#  'U.M.C.I.A.': 'NOUN',
#  'stalemate': 'NOUN',
#  'thumbing': 'VERB',
#  'Afrika': 'X',
#  "hens'": 'NOUN',
#  'fascinating': 'ADJ',
#  'sheepe': 'NOUN',
#  'demoralizing': 'VERB',
#  'monolith': 'NOUN',
#  'Bedridden': 'ADJ',
#  'whistling': 'VERB',
#  'soft-shoe': 'NOUN',
#  'Joan': 'NOUN',
#  'Trustees': 'NOUN',
#  'Papa-san': 'NOUN',
#  'Elegance': 'NOUN',
#  'Davidson': 'NOUN',
#  'Yet': 'CONJ',
#  'spherical': 'ADJ',
#  'ruler': 'NOUN',
#  'obligingly': 'ADV',
#  '$250': 'NOUN',
#  'shadings': 'NOUN',
#  'signposts': 'NOUN',
#  'centrality': 'NOUN',
#  'Alla': 'NOUN',
#  'Name': 'NOUN',
#  "government's": 'NOUN',
#  'tracers': 'NOUN',
#  'typescript': 'NOUN',
#  'ghetto': 'NOUN',
#  'electrodynamics': 'NOUN',
#  'frailest': 'ADJ',
#  'wishing': 'VERB',
#  'teakettle': 'NOUN',
#  'Ophthalmic': 'ADJ',
#  'hot': 'ADJ',
#  "She'll": 'PRT',
#  "rep'tation": 'NOUN',
#  'forecasters': 'NOUN',
#  'instances': 'NOUN',
#  'Indians': 'NOUN',
#  'Worcester': 'NOUN',
#  'archipelago': 'NOUN',
#  'transact': 'VERB',
#  'examines': 'VERB',
#  'appearance': 'NOUN',
#  'skyline': 'NOUN',
#  "Henri's": 'NOUN',
#  'Weltanschauung': 'X',
#  'sixteenth': 'ADJ',
#  'unfavorable': 'ADJ',
#  '$5,000': 'NOUN',
#  'sangiovanni': 'X',
#  'Librarians': 'NOUN',
#  'accuracy': 'NOUN',
#  'carefulness': 'NOUN',
#  'freer': 'ADJ',
#  'Kennett': 'NOUN',
#  'off-color': 'ADJ',
#  'dyspeptic': 'ADJ',
#  'dinnertime': 'NOUN',
#  'Exhibition': 'NOUN',
#  "James'": 'NOUN',
#  'Circumstances': 'NOUN',
#  'adjectives': 'NOUN',
#  'whip': 'NOUN',
#  'Agee': 'NOUN',
#  'epicure': 'NOUN',
#  'High-gain': 'NOUN',
#  "O'Sullivan": 'NOUN',
#  "Burke's": 'NOUN',
#  'rattle': 'NOUN',
#  'multi-millionaire': 'NOUN',
#  '14th': 'ADJ',
#  'hawkers': 'NOUN',
#  'Quince': 'NOUN',
#  'object': 'NOUN',
#  'richest': 'ADJ',
#  'correctness': 'NOUN',
#  'trundling': 'VERB',
#  'Today': 'NOUN',
#  'Philippians': 'NOUN',
#  'Howser': 'NOUN',
#  'Baines': 'NOUN',
#  'at': 'ADP',
#  'froth': 'NOUN',
#  'dealings': 'NOUN',
#  'figural': 'ADJ',
#  'Esnards': 'NOUN',
#  'Eleazar': 'NOUN',
#  'sidechairs': 'NOUN',
#  'paraphrase': 'NOUN',
#  '1871': 'NUM',
#  'garnet': 'NOUN',
#  'transistor': 'NOUN',
#  'weakness': 'NOUN',
#  'tangent': 'ADJ',
#  'hillbilly': 'NOUN',
#  'vibrant': 'ADJ',
#  'comparable': 'ADJ',
#  'kerygma': 'NOUN',
#  'editions': 'NOUN',
#  'attrition': 'NOUN',
#  'absence': 'NOUN',
#  'dowry': 'NOUN',
#  'chestnut': 'NOUN',
#  'Harmony': 'NOUN',
#  'sisters-in-law': 'NOUN',
#  "Harmony's": 'NOUN',
#  'disbursed': 'VERB',
#  'Resourceful': 'ADJ',
#  'bois': 'X',
#  'capitol': 'NOUN',
#  "Ada's": 'NOUN',
#  'guess': 'VERB',
#  'Oak': 'NOUN',
#  'forked': 'VERB',
#  'Lexington': 'NOUN',
#  'Thant': 'NOUN',
#  'traversing': 'VERB',
#  'shod': 'VERB',
#  'Estimate': 'NOUN',
#  'consonants': 'NOUN',
#  'Mlle': 'NOUN',
#  'sketches': 'NOUN',
#  'diplomacy': 'NOUN',
#  'Materialism': 'NOUN',
#  'volumetric': 'ADJ',
#  "pride's": 'NOUN',
#  "grownups'": 'NOUN',
#  'Chesly': 'NOUN',
#  'Cavanagh': 'NOUN',
#  'plucking': 'VERB',
#  'L.S.U.': 'NOUN',
#  'disservice': 'NOUN',
#  'Karipo': 'NOUN',
#  'Traditionalists': 'NOUN',
#  'miners': 'NOUN',
#  'rigged': 'VERB',
#  'Harrison': 'NOUN',
#  'good': 'ADJ',
#  'somehow': 'ADV',
#  'Say': 'VERB',
#  'fellow-countryman': 'NOUN',
#  'Sloanaker': 'NOUN',
#  "I'll": 'PRT',
#  'Refugees': 'NOUN',
#  'carousing': 'VERB',
#  'unsmiling': 'ADJ',
#  'insulate': 'VERB',
#  'SX-21': 'NOUN',
#  '1600': 'NUM',
#  "Cook's": 'NOUN',
#  'mentioned': 'VERB',
#  'Mayans': 'NOUN',
#  'solution-type': 'ADJ',
#  'cooped': 'VERB',
#  'hand-screened': 'ADJ',
#  'methyl': 'NOUN',
#  'illustrate': 'VERB',
#  'photograph': 'NOUN',
#  'implementing': 'VERB',
#  'naively': 'ADV',
#  'miscalculated': 'VERB',
#  'hello': 'PRT',
#  'synagogue': 'NOUN',
#  'every': 'DET',
#  'hundred-and-eighty-degree': 'ADJ',
#  'Inspect': 'VERB',
#  '50,000': 'NUM',
#  'turnpike': 'NOUN',
#  'Star': 'NOUN',
#  '14.5': 'NUM',
#  'implying': 'VERB',
#  'cockeyed': 'ADJ',
#  'nettled': 'VERB',
#  'Servant': 'NOUN',
#  'fawning': 'VERB',
#  'discrete': 'ADJ',
#  'substituted': 'VERB',
#  'Glee': 'NOUN',
#  'sordid': 'ADJ',
#  'change': 'NOUN',
#  'Istvan': 'NOUN',
#  'inevitably': 'ADV',
#  'varnish': 'NOUN',
#  'Kay': 'NOUN',
#  'harvested': 'VERB',
#  'Skopas': 'NOUN',
#  'unharmonious': 'ADJ',
#  'En': 'X',
#  'watching': 'VERB',
#  'mandrel': 'NOUN',
#  'lurid': 'ADJ',
#  'Bolsheviks': 'NOUN',
#  '2:32': 'NUM',
#  'subsidized': 'VERB',
#  'son-in-law': 'NOUN',
#  'sky-carving': 'ADJ',
#  'encroaching': 'VERB',
#  'kissing': 'VERB',
#  'Irma': 'NOUN',
#  'fretting': 'VERB',
#  '160,000': 'NUM',
#  'forthrightly': 'ADV',
#  'nozzle': 'NOUN',
#  'noses': 'NOUN',
#  'sound-truck': 'NOUN',
#  'Stan': 'NOUN',
#  'Atkinson': 'NOUN',
#  'powered': 'VERB',
#  'underworld': 'NOUN',
#  's-values': 'NOUN',
#  'held': 'VERB',
#  "Thompson's": 'NOUN',
#  'confining': 'VERB',
#  'commences': 'VERB',
#  'Gin': 'NOUN',
#  'boies': 'NOUN',
#  'firmer': 'ADJ',
#  'Carbondale': 'NOUN',
#  "Lalaurie's": 'NOUN',
#  'Green': 'ADJ',
#  '1,500': 'NUM',
#  'indestructible': 'ADJ',
#  'labeling': 'VERB',
#  'newly-married': 'ADJ',
#  'contemplated': 'VERB',
#  'Mytton': 'NOUN',
#  'shortsightedness': 'NOUN',
#  'Tredding': 'NOUN',
#  '2:01.1': 'NUM',
#  'stabilizes': 'VERB',
#  'surprised': 'VERB',
#  'accounts': 'NOUN',
#  'corresponds': 'VERB',
#  'pope': 'NOUN',
#  'Jungian': 'ADJ',
#  'portrayal': 'NOUN',
#  'camping': 'VERB',
#  '10-milligram': 'ADJ',
#  'dented': 'VERB',
#  'production': 'NOUN',
#  'bicycle': 'NOUN',
#  'Strip': 'NOUN',
#  '1.5': 'NUM',
#  '7026': 'NUM',
#  'prediction': 'NOUN',
#  "Gabriel's": 'NOUN',
#  'Affairs': 'NOUN',
#  'sailed': 'VERB',
#  'failing': 'VERB',
#  'Rulers': 'NOUN',
#  'Oneupmanship': 'NOUN',
#  "O'Casey": 'NOUN',
#  'onslaught': 'NOUN',
#  'Bulge': 'NOUN',
#  'Loan': 'NOUN',
#  'cronies': 'NOUN',
#  "Palace's": 'NOUN',
#  'Missionary': 'NOUN',
#  'velvet': 'NOUN',
#  'froze': 'VERB',
#  'States': 'NOUN',
#  'guilt': 'NOUN',
#  'infrequent': 'ADJ',
#  'infested': 'VERB',
#  'dully': 'ADV',
#  'vowing': 'VERB',
#  'tubing': 'NOUN',
#  'siege': 'NOUN',
#  'Groggins': 'NOUN',
#  'tan': 'ADJ',
#  'outfox': 'VERB',
#  'Meanwhile': 'ADV',
#  'lyriist': 'NOUN',
#  'reservation': 'NOUN',
#  'delays': 'NOUN',
#  'resins': 'NOUN',
#  'Wine': 'NOUN',
#  'rigs': 'NOUN',
#  'gaggle': 'NOUN',
#  'nonmetallic': 'ADJ',
#  'precautions': 'NOUN',
#  'unexpended': 'ADJ',
#  'sadly': 'ADV',
#  "'20's": 'NOUN',
#  'kingpin': 'NOUN',
#  'Democratique': 'X',
#  'circled': 'VERB',
#  'greying': 'VERB',
#  'Halfway': 'ADV',
#  'rescind': 'VERB',
#  'grit': 'NOUN',
#  'subspecies': 'NOUN',
#  'Keep': 'VERB',
#  'dirge': 'NOUN',
#  'grokking': 'NOUN',
#  'snarled': 'VERB',
#  'Stories': 'NOUN',
#  'compartments': 'NOUN',
#  'Onsets': 'NOUN',
#  'inquiry': 'NOUN',
#  'Chekhov': 'NOUN',
#  'anvil': 'NOUN',
#  'Jens': 'NOUN',
#  'bickering': 'VERB',
#  'Fitzroy': 'NOUN',
#  'Economy': 'NOUN',
#  "f'ovuh": 'ADP',
#  'invert': 'VERB',
#  'swami': 'NOUN',
#  'burned': 'VERB',
#  'Trastevere': 'NOUN',
#  'desk': 'NOUN',
#  'beans': 'NOUN',
#  'allegro': 'ADJ',
#  'pound': 'NOUN',
#  'head-tossing': 'NOUN',
#  'nettlesome': 'ADJ',
#  'slippery': 'ADJ',
#  'tactical': 'ADJ',
#  'fiberglas': 'NOUN',
#  'fast': 'ADV',
#  'nominate': 'VERB',
#  'bite': 'VERB',
#  'Ridiculing': 'VERB',
#  'scrapes': 'VERB',
#  'unachievable': 'ADJ',
#  'bout': 'NOUN',
#  'deteriorates': 'VERB',
#  'Johns-Manville': 'NOUN',
#  'oilseed': 'NOUN',
#  "I'd": 'PRT',
#  'lesion': 'NOUN',
#  '22': 'NUM',
#  'battles': 'NOUN',
#  'canto': 'X',
#  'Japan': 'NOUN',
#  'occupies': 'VERB',
#  '$172,400': 'NOUN',
#  'pectoral-ribcage': 'NOUN',
#  ':35.3': 'NUM',
#  'adverb': 'NOUN',
#  'daises': 'NOUN',
#  'Pictures': 'NOUN',
#  'Budgeting': 'VERB',
#  'Zenith': 'NOUN',
#  'Leavenworth': 'NOUN',
#  'north-south': 'ADJ',
#  'half-a-dozen': 'NOUN',
#  'public-school': 'NOUN',
#  'merchandise': 'NOUN',
#  'Hymn': 'NOUN',
#  "bo'sun's": 'NOUN',
#  'positivists': 'NOUN',
#  'boards': 'NOUN',
#  'non-absorbent': 'ADJ',
#  'waspish': 'ADJ',
#  'cliffhanging': 'VERB',
#  'drinking': 'VERB',
#  'Rockfork': 'NOUN',
#  'Merc': 'NOUN',
#  'Edna': 'NOUN',
#  'hibernate': 'VERB',
#  "They've": 'PRT',
#  'Feeley': 'NOUN',
#  'zealot': 'NOUN',
#  'oracle': 'NOUN',
#  'low-pitched': 'ADJ',
#  'liberties': 'NOUN',
#  'tactic': 'NOUN',
#  'automatic': 'ADJ',
#  'Sushi': 'X',
#  "Orleans'": 'NOUN',
#  'Tracing': 'VERB',
#  'Muzak': 'NOUN',
#  'fingertips': 'NOUN',
#  'fig': 'NOUN',
#  'SP-44005': 'NOUN',
#  'self-criticism': 'NOUN',
#  'globetrotter': 'NOUN',
#  'raided': 'VERB',
#  'algebraically': 'ADV',
#  'Sooner': 'ADV',
#  'world-shattering': 'ADJ',
#  'procedure': 'NOUN',
#  'affronted': 'VERB',
#  'demon-ridden': 'ADJ',
#  'strengthens': 'VERB',
#  'discs': 'NOUN',
#  'wrote': 'VERB',
#  'footing': 'VERB',
#  'creativeness': 'NOUN',
#  'drive-in': 'NOUN',
#  'privacy': 'NOUN',
#  'easing': 'VERB',
#  '375-degrees-C': 'NOUN',
#  'problem-solving': 'ADJ',
#  'bugging': 'VERB',
#  'haze': 'NOUN',
#  'ousted': 'VERB',
#  'Choreographed': 'VERB',
#  'teachings': 'NOUN',
#  'physiochemical': 'ADJ',
#  'Platonica': 'X',
#  'bigots': 'NOUN',
#  'ousting': 'VERB',
#  'psychosomatic': 'ADJ',
#  '$7,082': 'NOUN',
#  'Join': 'VERB',
#  '1,509': 'NUM',
#  'owning': 'NOUN',
#  'categories': 'NOUN',
#  'Auto': 'NOUN',
#  'readjusted': 'VERB',
#  'Idaho': 'NOUN',
#  'researcher': 'NOUN',
#  'Finalists': 'NOUN',
#  'Skolman': 'NOUN',
#  'door-to-door': 'NOUN',
#  'poison': 'NOUN',
#  "Kennan's": 'NOUN',
#  "doesn't": 'VERB',
#  'Garryowen': 'NOUN',
#  'Code': 'NOUN',
#  'reconstruct': 'VERB',
#  'holocaust': 'NOUN',
#  'non-thermal': 'ADJ',
#  'busses': 'NOUN',
#  'fumbled': 'VERB',
#  'Bessie': 'NOUN',
#  'pat': 'NOUN',
#  'wiggled': 'VERB',
#  'Prevents': 'VERB',
#  'Far': 'ADV',
#  'portfolio': 'NOUN',
#  'poles': 'NOUN',
#  'enriching': 'VERB',
#  'ol': 'ADJ',
#  '269': 'NUM',
#  'Tsarism': 'NOUN',
#  'long-haul': 'NOUN',
#  'Del': 'NOUN',
#  'Rockabye': 'PRT',
#  'smart': 'ADJ',
#  'Vikings': 'NOUN',
#  'Colefax': 'NOUN',
#  'uninterrupted': 'ADJ',
#  'aficionado': 'NOUN',
#  '$10.1': 'NOUN',
#  'estrangement': 'NOUN',
#  'setting': 'VERB',
#  'cowering': 'VERB',
#  'systematized': 'VERB',
#  'Keeler': 'NOUN',
#  'kiss': 'NOUN',
#  'November-December': 'NOUN',
#  'workingmen': 'NOUN',
#  '15-17': 'NUM',
#  'poem': 'NOUN',
#  'fulminate': 'VERB',
#  'chaplain': 'NOUN',
#  'operatic': 'ADJ',
#  'Bassi': 'NOUN',
#  'infatuation': 'NOUN',
#  'cleaner': 'ADJ',
#  'bees': 'NOUN',
#  'unsuspecting': 'ADJ',
#  '350,000': 'NUM',
#  'relegated': 'VERB',
#  'overpaid': 'VERB',
#  'Vaughn': 'NOUN',
#  "Sihanouk's": 'NOUN',
#  'interrelated': 'VERB',
#  'Eighteenth': 'ADJ',
#  'drafty': 'ADJ',
#  'kidnapped': 'VERB',
#  'dimensional': 'ADJ',
#  'Cal': 'NOUN',
#  'deposited': 'VERB',
#  'betrays': 'VERB',
#  'goitre': 'NOUN',
#  'cardiac': 'ADJ',
#  'untellable': 'ADJ',
#  'Maggie': 'NOUN',
#  'Mohammedanism': 'NOUN',
#  'Sonenberg': 'NOUN',
#  'renamed': 'VERB',
#  'hurry': 'NOUN',
#  'reappraisal': 'NOUN',
#  'epicenter': 'NOUN',
#  'Relax': 'VERB',
#  'about-faced': 'VERB',
#  'Success': 'NOUN',
#  'depending': 'ADP',
#  'sensibly': 'ADV',
#  'woke': 'VERB',
#  'glistened': 'VERB',
#  'cargo': 'NOUN',
#  "Ptolemy's": 'NOUN',
#  'relativity': 'NOUN',
#  'folds': 'NOUN',
#  'adroitness': 'NOUN',
#  '$19.3': 'NOUN',
#  'fifty-third': 'ADJ',
#  'fountain-falls': 'NOUN',
#  'kilowatt-hour': 'NOUN',
#  'Latest': 'ADJ',
#  'juke': 'NOUN',
#  'cowpuncher': 'NOUN',
#  'beatnik': 'NOUN',
#  'both': 'DET',
#  'Bani': 'NOUN',
#  'activating': 'VERB',
#  'muttered': 'VERB',
#  'One-Leg': 'ADJ',
#  'structure': 'NOUN',
#  'Expressway': 'NOUN',
#  'take': 'VERB',
#  'Alone': 'ADV',
#  'pickins': 'NOUN',
#  'Pfaff': 'NOUN',
#  'desirability': 'NOUN',
#  'preliminary': 'ADJ',
#  'specimens': 'NOUN',
#  'signatures': 'NOUN',
#  'Corrette': 'NOUN',
#  'dignitaries': 'NOUN',
#  'executor': 'NOUN',
#  'pollen-and-nectar': 'NOUN',
#  'Krasnik': 'NOUN',
#  'occasion': 'NOUN',
#  'guitars': 'NOUN',
#  'therapy': 'NOUN',
#  'Socola': 'NOUN',
#  "Leeds'": 'NOUN',
#  'persuasively': 'ADV',
#  "weeks'": 'NOUN',
#  'Townley': 'NOUN',
#  'stockbroker': 'NOUN',
#  'Han': 'NOUN',
#  'pranha': 'NOUN',
#  'worshipped': 'VERB',
#  "Williams's": 'NOUN',
#  'grandma': 'NOUN',
#  'buss': 'NOUN',
#  'conference': 'NOUN',
#  'hinted': 'VERB',
#  'instant': 'NOUN',
#  'honeymoon': 'NOUN',
#  'five-ply': 'ADJ',
#  'marring': 'VERB',
#  'anti-human': 'ADJ',
#  'Enright': 'NOUN',
#  'rejoices': 'VERB',
#  'beings': 'NOUN',
#  'larks': 'NOUN',
#  'Bibliography': 'NOUN',
#  'was': 'VERB',
#  'fille': 'X',
#  'driven': 'VERB',
#  'reinvestigation': 'NOUN',
#  'sheer': 'ADJ',
#  'Fiddlesticks': 'PRT',
#  'assessors': 'NOUN',
#  'Comment': 'NOUN',
#  'Silone': 'NOUN',
#  'strongly': 'ADV',
#  '1/3': 'NUM',
#  'overrun': 'VERB',
#  'recited': 'VERB',
#  'durable': 'ADJ',
#  'Reporters': 'NOUN',
#  'JYJ': 'NOUN',
#  'Prize': 'NOUN',
#  'piracy': 'NOUN',
#  'dunes': 'NOUN',
#  'treelike': 'ADJ',
#  'opportunities': 'NOUN',
#  'Baltimore': 'NOUN',
#  'nectareous': 'ADJ',
#  're-run': 'VERB',
#  'definitions': 'NOUN',
#  'cross': 'VERB',
#  '1577': 'NUM',
#  'pardon': 'NOUN',
#  'mystics': 'NOUN',
#  'premiere': 'NOUN',
#  'oil-well': 'NOUN',
#  'Loren': 'NOUN',
#  'Braun': 'NOUN',
#  "Benefactor's": 'NOUN',
#  'flapping': 'VERB',
#  'TV': 'NOUN',
#  'which': 'DET',
#  'enthusiast': 'NOUN',
#  'adequate': 'ADJ',
#  'classical': 'ADJ',
#  'handwriting': 'NOUN',
#  'coworkers': 'NOUN',
#  'evolving': 'VERB',
#  'comfortable': 'ADJ',
#  'handbook': 'NOUN',
#  'availing': 'VERB',
#  'old-grad-type': 'NOUN',
#  'Potsdam': 'NOUN',
#  'cosmopolitan': 'ADJ',
#  'compromises': 'NOUN',
#  'Prior': 'ADV',
#  'Bah': 'PRT',
#  'numerology': 'NOUN',
#  'chrome': 'NOUN',
#  'nestled': 'VERB',
#  'inalienable': 'ADJ',
#  'jumps': 'NOUN',
#  "Prentice's": 'NOUN',
#  'coffee-house': 'NOUN',
#  'Jay': 'NOUN',
#  'Marriage': 'NOUN',
#  'deprive': 'VERB',
#  'gradualist': 'NOUN',
#  'giant': 'ADJ',
#  'parable': 'NOUN',
#  'appropriation': 'NOUN',
#  'demographiques': 'X',
#  'astonishment': 'NOUN',
#  'Nagrin': 'NOUN',
#  'volume': 'NOUN',
#  'permanently': 'ADV',
#  'chief': 'ADJ',
#  'wetlands': 'NOUN',
#  'appreciable': 'ADJ',
#  'injustices': 'NOUN',
#  '1643': 'NUM',
#  'kiloton': 'NOUN',
#  'Instead': 'ADV',
#  'Feverishly': 'ADV',
#  'Circumstance': 'NOUN',
#  'emitted': 'VERB',
#  'resurrected': 'VERB',
#  'arranging': 'VERB',
#  'denting': 'VERB',
#  'likes': 'VERB',
#  'Draw-file': 'VERB',
#  'middle-age': 'NOUN',
#  'Emilio': 'NOUN',
#  'advancing': 'VERB',
#  'tongue-thrusting': 'NOUN',
#  'atypical': 'ADJ',
#  'Dawson': 'NOUN',
#  'presumptions': 'NOUN',
#  'Guatemala': 'NOUN',
#  'metal-tasting': 'ADJ',
#  ...}

# %% [markdown]
# ## Making Predictions with a Model

# %%
def replace_unknown(sequence):
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]

# %% [markdown]
# ## Example Decoding Sequences with MFC Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Predicted Labels: \n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
# Out:
# Sentence Key: b100-28144
#
# Predicted Labels:
# -----------------
# ['CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.']
# Sentence Key: b100-23146
#
# Predicted Labels:
# -----------------
# ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
# Sentence Key: b100-35462
#
# Predicted Labels:
# -----------------
# ['DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', '<MISSING>', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADV', 'NOUN', '.']

# %% [markdown]
# ## Evaluating Model Accuracy

# %%
def accuracy(X, Y, model):
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct/total_predictions

# %% [markdown]
# ## Evaluate the accuracy of the MFC tagger

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("Training Accuracy for the MFC Model: {:.2f}%".format(100*mfc_training_acc))
mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("Testing Accuracy for the MFC Model: {:.2f}%".format(100*mfc_testing_acc))
# Out:
# Training Accuracy for the MFC Model: 95.71%
# Testing Accuracy for the MFC Model: 93.13%

# %% [markdown]
# ## Bigram Counts

# %%
import itertools
def pairwise(iterable):
    t, t_1 = itertools.tee(iterable)
    next(t_1, 'end')
    return zip(t, t_1)

def bigram_counts(sequences):
    return(dict(Counter(pairwise(sequences))))

tag_bigrams = bigram_counts(tags)

# %% [markdown]
# ## Sequence Starting Counts

# %%
def starting_counts(sequences):
    return(dict(Counter(i[0] for i in sequences)))

# %%
tags_label = data.Y
tag_starts = starting_counts(tags_label)

# %%
tag_starts
# Out:
# {'NOUN': 8093,
#  'CONJ': 2817,
#  'PRT': 2103,
#  'DET': 12238,
#  'PRON': 9157,
#  'ADP': 7044,
#  'ADJ': 1969,
#  'ADV': 5238,
#  'VERB': 2588,
#  'NUM': 964,
#  '.': 5099,
#  'X': 30}

# %% [markdown]
# ## Sequence Ending Counts

# %%
def ending_counts(sequences):
    return(dict(Counter(i[-1] for i in sequences)))

# %%
tag_ends = ending_counts(tags_label)
tag_ends
# Out:
# {'.': 56149,
#  'ADJ': 31,
#  'ADV': 20,
#  'NOUN': 914,
#  'NUM': 80,
#  'PRON': 5,
#  'ADP': 8,
#  'VERB': 102,
#  'DET': 18,
#  'PRT': 9,
#  'CONJ': 2,
#  'X': 2}

# %% [markdown]
# ## Basic HMM Tagger
# - Use the tag unigrams and bigrams calculated above to construct a hidden Markov tagger.
#
# - Add one state per tag
#     - The emission distribution at each state should be estimated with the formula: $P(w|t) = \frac{C(t, w)}{C(t)}$
# - Add an edge from the starting state `basic_model.start` to each tag
#     - The transition probability should be estimated with the formula: $P(t|start) = \frac{C(start, t)}{C(start)}$
# - Add an edge from each tag to the end state `basic_model.end`
#     - The transition probability should be estimated with the formula: $P(end|t) = \frac{C(t, end)}{C(t)}$
# - Add an edge between _every_ pair of tags
#     - The transition probability should be estimated with the formula: $P(t_2|t_1) = \frac{C(t_1, t_2)}{C(t_1)}$

# %%
basic_model = HiddenMarkovModel(name="base-hmm-tagger")
tags = [tag for _, tag in data.stream()]
words = [word for word, _ in data.stream()]
emission_counts = pair_counts(tags, words)
states = {}

# %%
def unigram_counts(sequences):

    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
tag_unigrams = unigram_counts(tags)

# %%
for pos_tag in data.tagset:
    emission_probabilities = dict()
    
    for word, occurence in emission_counts[pos_tag].items():
        emission_probabilities[word] = occurence/tag_unigrams[pos_tag]
    
    tag_distribution = DiscreteDistribution(emission_probabilities)
    state = State(tag_distribution, name=pos_tag)
    states[pos_tag] = state
    basic_model.add_state(state)
    
emission_probabilities
# Out:
# {'there': 0.05659667029197691,
#  'to': 0.6166652723165732,
#  'Such': 0.0015058981008951727,
#  'half': 0.009704676650213335,
#  'all': 0.10658412114113612,
#  'up': 0.07107002426169162,
#  'out': 0.06776541454028277,
#  "you'll": 0.0025098301681586214,
#  "It's": 0.00669288044842299,
#  "kid's": 0.00012549150840793105,
#  'on': 0.02325775955826989,
#  'off': 0.01999498033966368,
#  'down': 0.029030368945034718,
#  "that's": 0.003764745252237932,
#  "it's": 0.005939931397975403,
#  "you'd": 0.0011712540784740233,
#  "you're": 0.003890236760645863,
#  'in': 0.019451183803229313,
#  'over': 0.01602108257341253,
#  'such': 0.01146155776792437,
#  'There': 0.03392453777294403,
#  "he'd": 0.0031372877101982764,
#  'To': 0.010583117209068854,
#  "We've": 0.0008784405588555174,
#  'Sonuvabitch': 4.183050280264369e-05,
#  "I'm": 0.011252405253911153,
#  "That's": 0.0040575587718564374,
#  "We're": 0.001087593072868736,
#  'quite': 0.0017150506149083912,
#  'Goodbye': 8.366100560528738e-05,
#  "You're": 0.002426169162553334,
#  "who's": 0.0003346440224211495,
#  'lo': 4.183050280264369e-05,
#  "I've": 0.005228812850330461,
#  'All': 0.008784405588555174,
#  'Well': 0.004852338325106668,
#  "he's": 0.0025098301681586214,
#  "I'll": 0.0075713210072785074,
#  'Oh': 0.004559524805488162,
#  "There's": 0.0023425081569480467,
#  "I'd": 0.004350372291474944,
#  "They'll": 0.0007111185476449427,
#  'Uh-huh': 0.00016732201121057475,
#  "she'd": 0.002300677654145403,
#  'hell': 0.00012549150840793105,
#  "Where'd": 0.00016732201121057475,
#  "they'd": 0.0010039320672634484,
#  "camera's": 4.183050280264369e-05,
#  'Hell': 0.0004601355308290806,
#  'through': 0.002551660670961265,
#  "You'll": 0.0012549150840793107,
#  "you've": 0.0017987116205136786,
#  'Dammit': 0.00016732201121057475,
#  'Okay': 0.000543796536434368,
#  'Hey': 0.0004601355308290806,
#  "Wally's": 8.366100560528738e-05,
#  "there's": 0.0022170166485401153,
#  "we'll": 0.001087593072868736,
#  'well': 0.0009202710616581612,
#  "They're": 0.0011712540784740233,
#  "leg's": 4.183050280264369e-05,
#  "it'll": 0.0003764745252237932,
#  "they'll": 0.0006274575420396553,
#  "We'll": 0.00158955910650046,
#  'many': 0.0008366100560528737,
#  "we'd": 0.0009202710616581612,
#  'Over': 0.0003764745252237932,
#  "who'd": 0.0003346440224211495,
#  'Down': 8.366100560528738e-05,
#  'Many': 0.00020915251401321843,
#  "they're": 0.0015477286036978165,
#  'Bong': 0.0002509830168158621,
#  'Out': 0.000543796536434368,
#  "he'll": 0.000669288044842299,
#  "she's": 0.0009202710616581612,
#  'say': 0.0005856270392370117,
#  'damnit': 4.183050280264369e-05,
#  'oh': 0.00041830502802643686,
#  "we're": 0.0014640675980925292,
#  'ahem': 4.183050280264369e-05,
#  "Who's": 0.00041830502802643686,
#  "sun's": 4.183050280264369e-05,
#  'Jesus': 0.00020915251401321843,
#  "what's": 0.0006274575420396553,
#  "we've": 0.000543796536434368,
#  "They've": 0.0003346440224211495,
#  'Amen': 0.00029281351961850583,
#  'amen': 0.00020915251401321843,
#  "water's": 4.183050280264369e-05,
#  'Hello': 0.0002509830168158621,
#  'about': 0.0008366100560528737,
#  "He'd": 0.0009621015644608048,
#  "other's": 0.0003764745252237932,
#  "What's": 0.00158955910650046,
#  "She's": 0.001087593072868736,
#  'damn': 0.00012549150840793105,
#  "else's": 0.0003764745252237932,
#  "How's": 0.0003764745252237932,
#  'huh': 0.00020915251401321843,
#  'Ah': 0.0004601355308290806,
#  "Nobody's": 8.366100560528738e-05,
#  "He's": 0.00271898268217184,
#  "She'd": 0.000543796536434368,
#  "Summer's": 4.183050280264369e-05,
#  'alas': 0.0002509830168158621,
#  'Alas': 0.00016732201121057475,
#  "You've": 0.0010039320672634484,
#  'rather': 0.00020915251401321843,
#  "There'll": 4.183050280264369e-05,
#  "cane's": 4.183050280264369e-05,
#  "Kitty's": 0.00016732201121057475,
#  "y'know": 8.366100560528738e-05,
#  "Them's": 8.366100560528738e-05,
#  'Atta': 8.366100560528738e-05,
#  'Uhhu': 0.00012549150840793105,
#  'goddamit': 4.183050280264369e-05,
#  "She'll": 0.0002509830168158621,
#  'good-bye': 0.00016732201121057475,
#  "father's": 4.183050280264369e-05,
#  "Someone's": 4.183050280264369e-05,
#  'zoooop': 4.183050280264369e-05,
#  "What'd": 4.183050280264369e-05,
#  'OK.': 4.183050280264369e-05,
#  'gosh': 4.183050280264369e-05,
#  'My': 4.183050280264369e-05,
#  'eh': 0.00012549150840793105,
#  "It'll": 0.0003764745252237932,
#  'Good-by': 4.183050280264369e-05,
#  'zounds': 8.366100560528738e-05,
#  "they've": 0.0003346440224211495,
#  'Please': 0.00029281351961850583,
#  "what're": 4.183050280264369e-05,
#  'bannnnnng': 4.183050280264369e-05,
#  "'tis": 8.366100560528738e-05,
#  'Hmm': 4.183050280264369e-05,
#  'diddle': 4.183050280264369e-05,
#  'Kee-reist': 4.183050280264369e-05,
#  "sun'll": 4.183050280264369e-05,
#  "out'n": 8.366100560528738e-05,
#  "Where's": 0.0002509830168158621,
#  'Indeed': 8.366100560528738e-05,
#  "'tain't": 4.183050280264369e-05,
#  'Jee-sus': 4.183050280264369e-05,
#  "name's": 0.00016732201121057475,
#  'hello': 0.00016732201121057475,
#  "He'll": 0.0005856270392370117,
#  'Uh': 0.00012549150840793105,
#  "that'd": 4.183050280264369e-05,
#  "Here's": 0.00041830502802643686,
#  'Gosh': 0.00012549150840793105,
#  "Myra's": 4.183050280264369e-05,
#  "We'd": 0.00041830502802643686,
#  "this'll": 4.183050280264369e-05,
#  "Mack's": 8.366100560528738e-05,
#  "Jack's": 4.183050280264369e-05,
#  'So': 4.183050280264369e-05,
#  'Half': 0.0002509830168158621,
#  'O.K.': 0.00029281351961850583,
#  "everything's": 8.366100560528738e-05,
#  'dear': 4.183050280264369e-05,
#  "Rob's": 4.183050280264369e-05,
#  "Guardino's": 4.183050280264369e-05,
#  "sky's": 8.366100560528738e-05,
#  'please': 0.0003346440224211495,
#  "thet's": 4.183050280264369e-05,
#  'good-night': 4.183050280264369e-05,
#  'Up': 0.0005019660336317242,
#  'O': 0.00041830502802643686,
#  'Golly': 4.183050280264369e-05,
#  "Pietro's": 4.183050280264369e-05,
#  "undersecretary's": 4.183050280264369e-05,
#  'shucks': 4.183050280264369e-05,
#  'Bravo': 4.183050280264369e-05,
#  'insomma': 4.183050280264369e-05,
#  "Someone'll": 4.183050280264369e-05,
#  "They'd": 0.0002509830168158621,
#  "Where're": 4.183050280264369e-05,
#  "'ello": 4.183050280264369e-05,
#  'across': 0.0005019660336317242,
#  "Knife's": 8.366100560528738e-05,
#  "Pa's": 4.183050280264369e-05,
#  "company's": 0.00012549150840793105,
#  'ba-a-a': 4.183050280264369e-05,
#  'Um': 8.366100560528738e-05,
#  'theare': 4.183050280264369e-05,
#  'Wow': 4.183050280264369e-05,
#  'God': 8.366100560528738e-05,
#  'dammit': 0.00012549150840793105,
#  'Aah': 4.183050280264369e-05,
#  'good-by': 4.183050280264369e-05,
#  "You'd": 0.0003346440224211495,
#  "Baseball's": 4.183050280264369e-05,
#  'Off': 0.00016732201121057475,
#  "That'll": 0.00020915251401321843,
#  "Katharine's": 4.183050280264369e-05,
#  "Arthur's": 4.183050280264369e-05,
#  'Christ': 8.366100560528738e-05,
#  'Mmm': 8.366100560528738e-05,
#  'Hooray': 4.183050280264369e-05,
#  "boat's": 4.183050280264369e-05,
#  'Heigh-ho': 4.183050280264369e-05,
#  'dairy-oh': 4.183050280264369e-05,
#  "Somebody's": 8.366100560528738e-05,
#  'Shh': 4.183050280264369e-05,
#  'uh-huh': 4.183050280264369e-05,
#  'Eh': 0.00020915251401321843,
#  'Howdy': 4.183050280264369e-05,
#  'Good-bye': 8.366100560528738e-05,
#  'bang': 8.366100560528738e-05,
#  "guy's": 8.366100560528738e-05,
#  'Goolick': 4.183050280264369e-05,
#  'goooolick': 4.183050280264369e-05,
#  "t'lah": 4.183050280264369e-05,
#  'hey': 0.00016732201121057475,
#  'Welcome': 0.00012549150840793105,
#  'Hurrah': 0.00012549150840793105,
#  'Fiddlesticks': 4.183050280264369e-05,
#  'Quite': 4.183050280264369e-05,
#  "there'll": 8.366100560528738e-05,
#  "kind's": 4.183050280264369e-05,
#  'ah': 0.00012549150840793105,
#  'Whoa': 4.183050280264369e-05,
#  'Haw': 4.183050280264369e-05,
#  'Gee': 8.366100560528738e-05,
#  'indeed': 4.183050280264369e-05,
#  'Keerist': 4.183050280264369e-05,
#  'after': 4.183050280264369e-05,
#  "nobody'd": 4.183050280264369e-05,
#  'Hi': 0.0002509830168158621,
#  "she'll": 0.00016732201121057475,
#  "Penny's": 8.366100560528738e-05,
#  'Aw': 8.366100560528738e-05,
#  "it'd": 0.00012549150840793105,
#  'Say': 4.183050280264369e-05,
#  "Springfield's": 4.183050280264369e-05,
#  'Man': 4.183050280264369e-05,
#  "fire's": 8.366100560528738e-05,
#  'up-pp': 4.183050280264369e-05,
#  'Hoa-whup': 4.183050280264369e-05,
#  'sir': 4.183050280264369e-05,
#  'crap': 4.183050280264369e-05,
#  'Zingggg-O': 4.183050280264369e-05,
#  'Oh-the-pain-of-it': 4.183050280264369e-05,
#  'golly': 4.183050280264369e-05,
#  "duds'd": 4.183050280264369e-05,
#  'goodbye': 0.00012549150840793105,
#  'sake': 4.183050280264369e-05,
#  'uh': 8.366100560528738e-05,
#  'outta': 8.366100560528738e-05,
#  'Da-da-da-dum': 4.183050280264369e-05,
#  'Toot': 0.00012549150840793105,
#  "Somebody'll": 4.183050280264369e-05,
#  'oops': 4.183050280264369e-05,
#  "C'mon": 0.00012549150840793105,
#  'nary': 4.183050280264369e-05,
#  'Kaboom': 4.183050280264369e-05,
#  'Crunch': 4.183050280264369e-05,
#  'Sure-sure': 4.183050280264369e-05,
#  'Why': 0.00012549150840793105,
#  'godamit': 4.183050280264369e-05,
#  'goodnight': 8.366100560528738e-05,
#  "hell's": 4.183050280264369e-05,
#  'doggone': 4.183050280264369e-05,
#  'Pap-pap-pap-hey': 4.183050280264369e-05,
#  "Everything's": 4.183050280264369e-05,
#  "Buckhorn's": 4.183050280264369e-05,
#  'Yesiree': 4.183050280264369e-05,
#  'Ahm': 4.183050280264369e-05,
#  "t'jawn": 4.183050280264369e-05,
#  "Kate's": 4.183050280264369e-05,
#  'okay': 8.366100560528738e-05,
#  "Whyn't": 4.183050280264369e-05,
#  'Hubba': 4.183050280264369e-05,
#  'hubba': 4.183050280264369e-05,
#  'Yalagaloo': 4.183050280264369e-05,
#  'pip': 8.366100560528738e-05,
#  "Arlene's": 4.183050280264369e-05,
#  'Aaawww': 4.183050280264369e-05,
#  'buzz-buzz-buzz': 4.183050280264369e-05,
#  "bastard's": 4.183050280264369e-05,
#  "cowhand'd": 4.183050280264369e-05,
#  "Crosson's": 4.183050280264369e-05,
#  "Bill's": 4.183050280264369e-05,
#  "Mahzeer's": 8.366100560528738e-05,
#  'Bah': 4.183050280264369e-05,
#  "Great's": 4.183050280264369e-05,
#  "there'd": 0.00012549150840793105,
#  'In': 4.183050280264369e-05,
#  "throat's": 4.183050280264369e-05,
#  'goddammit': 4.183050280264369e-05,
#  'my': 4.183050280264369e-05,
#  "ye're": 8.366100560528738e-05,
#  'Harro': 4.183050280264369e-05,
#  "doctor's": 4.183050280264369e-05,
#  "t'": 4.183050280264369e-05,
#  'Gawdamighty': 4.183050280264369e-05,
#  'Keeeerist': 4.183050280264369e-05,
#  'tarantara': 4.183050280264369e-05,
#  'rum-tum-tum': 4.183050280264369e-05,
#  'boom-boom-boom': 4.183050280264369e-05,
#  "you's": 4.183050280264369e-05,
#  'Ugh': 4.183050280264369e-05,
#  'Shucks': 4.183050280264369e-05,
#  "oystchers'll": 4.183050280264369e-05,
#  'Oooo': 4.183050280264369e-05,
#  'Goddammit': 4.183050280264369e-05,
#  'Aye-yah-ah-ah': 4.183050280264369e-05,
#  'Pugh': 4.183050280264369e-05,
#  'Henh': 4.183050280264369e-05,
#  'Krist': 4.183050280264369e-05,
#  'M-m-m': 4.183050280264369e-05,
#  "granite's": 4.183050280264369e-05,
#  'Hmpf': 4.183050280264369e-05,
#  'boy': 4.183050280264369e-05,
#  "Seaton's": 4.183050280264369e-05,
#  "'mon": 4.183050280264369e-05,
#  'uh-uh': 4.183050280264369e-05,
#  'Goodby': 4.183050280264369e-05,
#  "wife's": 4.183050280264369e-05,
#  "one's": 4.183050280264369e-05,
#  'farewell': 4.183050280264369e-05,
#  'honest-to-Betsy': 4.183050280264369e-05,
#  "rain's": 4.183050280264369e-05,
#  'pugh': 4.183050280264369e-05,
#  "Y're": 8.366100560528738e-05,
#  "today'll": 4.183050280264369e-05,
#  "Gyp'll": 4.183050280264369e-05,
#  "here's": 4.183050280264369e-05,
#  'Yooee': 4.183050280264369e-05,
#  "anybody'd": 4.183050280264369e-05,
#  "roulette's": 4.183050280264369e-05,
#  'Bye': 4.183050280264369e-05,
#  "Tim's": 4.183050280264369e-05,
#  'Jumping': 4.183050280264369e-05,
#  'Jerusalem': 4.183050280264369e-05,
#  'sure-sure': 4.183050280264369e-05,
#  'Hush': 4.183050280264369e-05,
#  "John'll": 4.183050280264369e-05,
#  'ha': 8.366100560528738e-05,
#  "Blackwell's": 4.183050280264369e-05,
#  'On': 4.183050280264369e-05,
#  "Breed's": 4.183050280264369e-05,
#  'Goddamn': 4.183050280264369e-05,
#  "Lucille's": 4.183050280264369e-05,
#  "Nothing's": 4.183050280264369e-05,
#  'a-gracious': 4.183050280264369e-05,
#  "Who'd": 4.183050280264369e-05,
#  'it': 4.183050280264369e-05,
#  "W.'s": 4.183050280264369e-05,
#  'Goody': 4.183050280264369e-05,
#  'goody': 4.183050280264369e-05,
#  'Aaa-ee': 4.183050280264369e-05,
#  "How'd": 8.366100560528738e-05,
#  'Mmmm': 4.183050280264369e-05,
#  'huh-uh': 4.183050280264369e-05,
#  'Roger': 4.183050280264369e-05,
#  'Chrissake': 4.183050280264369e-05,
#  "Pa'd": 4.183050280264369e-05,
#  'Jeepers': 4.183050280264369e-05,
#  'Creepers': 4.183050280264369e-05,
#  "fat's": 4.183050280264369e-05,
#  'ther': 4.183050280264369e-05,
#  'hush': 4.183050280264369e-05,
#  "how'd": 4.183050280264369e-05,
#  'Toot-toot': 4.183050280264369e-05,
#  "Black's": 4.183050280264369e-05,
#  "money's": 4.183050280264369e-05,
#  'Boy': 4.183050280264369e-05,
#  'Sssshoo': 4.183050280264369e-05,
#  'Whee': 4.183050280264369e-05,
#  'Bullshit': 4.183050280264369e-05,
#  'Hurray': 4.183050280264369e-05,
#  'see': 4.183050280264369e-05,
#  "Heat's": 4.183050280264369e-05,
#  'Rockabye': 4.183050280264369e-05,
#  'Umm': 4.183050280264369e-05,
#  'uhhu': 4.183050280264369e-05,
#  "There'd": 4.183050280264369e-05,
#  'whoosh': 4.183050280264369e-05,
#  'Glory': 4.183050280264369e-05,
#  'Be': 4.183050280264369e-05,
#  'Hallelujah': 4.183050280264369e-05,
#  "Who'll": 4.183050280264369e-05,
#  'Howda': 4.183050280264369e-05,
#  'presto': 4.183050280264369e-05,
#  'unnnt': 4.183050280264369e-05,
#  "Why'n": 4.183050280264369e-05,
#  "Ike's": 4.183050280264369e-05,
#  'hoo-pig': 4.183050280264369e-05,
#  'Morning': 4.183050280264369e-05,
#  'help': 4.183050280264369e-05,
#  "Skolman's": 4.183050280264369e-05,
#  'Ahah': 4.183050280264369e-05,
#  'Ah-ah': 4.183050280264369e-05,
#  "level's": 4.183050280264369e-05,
#  "Celie's": 4.183050280264369e-05}

# %%
for pos_tag in data.tagset:
    state = states[pos_tag]
    tags_label = data.Y
    tag_starts = starting_counts(tags_label)
    tag_ends = ending_counts(tags_label)
    start_probability = tag_starts[pos_tag]/sum(tag_starts.values())
    basic_model.add_transition(basic_model.start, state, start_probability)
    end_probability = tag_ends[pos_tag]/sum(tag_ends.values())
    basic_model.add_transition(state, basic_model.end, end_probability)

# %%
for tag_1 in data.tagset:
    state_1 = states[tag_1]
    sum_of_probabilities = 0
    for tag_2 in data.tagset:
        state_2 = states[tag_2]
        bigram = (tag_1, tag_2)
        transition_probability = tag_bigrams[bigram]/tag_unigrams[tag_1]
        sum_of_probabilities += transition_probability
        basic_model.add_transition(state_1, state_2, transition_probability)

# %%
basic_model.bake()
print("Number of nodes or states: ", basic_model.node_count())
print("Number of edges: ", basic_model.edge_count())
# Out:
# Number of nodes or states:  14
# Number of edges:  168

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, basic_model)
print("Training Accuracy for the Basic HMM Model: {:.2f}%".format(100 * hmm_training_acc))
hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, basic_model)
print("Testing Accuracy for the Basic HMM Model: {:.2f}%".format(100 * hmm_testing_acc))
# Out:
# Training Accuracy for the Basic HMM Model: 97.53%
# Testing Accuracy for the Basic HMM Model: 96.16%

# %% [markdown]
# ### Example Decoding Sequences with the HMM Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Predicted Labels:\n--------------")
    print(simplify_decoding(data.sentences[key].words, basic_model))
    print()
    print("Actual Labels:\n-----------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-28144
#
# Predicted Labels:
# --------------
# ['CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.']
#
# Actual Labels:
# -----------
# ('CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.')
#
#
# Sentence Key: b100-23146
#
# Predicted Labels:
# --------------
# ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
#
# Actual Labels:
# -----------
# ('PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
#
# Sentence Key: b100-35462
#
# Predicted Labels:
# --------------
# ['DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.']
#
# Actual Labels:
# -----------
# ('DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')
